# %% [markdown]
# # Chapter 4: Data Visualization

# %%
low_memory=False
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 4.1 Introduction & Problem Setting

# %% [markdown]
# There are many options for visualizing data. See the figure below by Claus Wilke for examples of common approaches.
#
# ![](https://bookdown.org/wangminjie/R4DS/images/common-aesthetics.png)
#
# Not all visualization types are appropriate for every data type. Let's explore this with the Titanic dataset!
#
# By now you should be familiar with the different columns and data types. Create an interesting plot using the Titanic data! Remember that **the story is crucial**. What are you trying to show, and how can you use visual design to tell that story effectively? Keep the following design elements in mind (not all apply to every plot):
#
# - **Position:** The position is determined by the plot type (e.g., `plot(x, y)`, `scatter(x, y)`, `hist(x)`)
# - **Shape:** You can use the `marker` option in matplotlib. Note: you can only use one marker per plot. Can you think of a workaround?
# - **Size:** You can use the `s` option in matplotlib
# - **Color:** You can use the `c` or `color` option (`color` is preferred for a single color; `c` for an array)
# - **Line width:** You can use the `linewidth` option in matplotlib
# - **Line type:** You can use the `linestyle` option in matplotlib

# %% [markdown]
# ## 4.2 Data Loading & Exploration

# %% [markdown]
# *Load your Titanic data. You can use the cleaned dataset you prepared last week, or download the version from Canvas.*

# %%
newdf=pd.read_csv("/Users/mohammedsadmanuddin/data analysis/Data exploration/Titanic_cleaned.csv",sep=",")
newdf
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             1            2       1.0     1.0
# 1             3            4       1.0     1.0
# 2             6            7       0.0     1.0
# 3            10           11       1.0     3.0
# 4            11           12       1.0     1.0
# ..          ...          ...       ...     ...
# 178         871          872       1.0     1.0
# 179         872          873       0.0     1.0
# 180         879          880       1.0     1.0
# 181         887          888       1.0     1.0
# 182         889          890       1.0     1.0
#
#                                                   Name     Sex   Age  SibSp  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 1         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 2                              McCarthy, Mr. Timothy J    male  54.0    0.0
# 3                      Sandstrom, Miss. Marguerite Rut  female   4.0    1.0
# ...

# %% [markdown]
# ## 4.3 Data Visualization

# %% [markdown]
# *Create your visualizations! Make sure you tell an actual story with your plots, not just show raw graphics. Try to make at least three visualizations that reveal different insights from the data.*

# %%
titanic_df=newdf.iloc[:50]
titanic_pass=titanic_df["PassengerId"]
titanic_age=titanic_df["Age"]
titanic_sur=titanic_df["Survived"]
titanic_gender=titanic_df["Sex"].value_counts()



fig=plt.figure(figsize=(10,10))
ax1=fig.add_subplot(2,2,1)
ax1.plot(titanic_pass,titanic_age,color='r')
ax1.set_xlabel("PassengerID")
ax1.set_ylabel("Age")
ax2=fig.add_subplot(2,2,2)
ax2.plot(titanic_pass,titanic_sur,color='b')
ax2.set_xlabel("PassengerID")
ax2.set_ylabel("Survival")
ax3=fig.add_subplot(2,2,3)
ax3.scatter(titanic_pass,titanic_age,color='b')
ax3.set_xlabel("PassengerID")
ax3.set_ylabel("Age")
ax3.legend()
ax4=fig.add_subplot(2,2,4)
ax4.bar(titanic_gender.index,titanic_gender.values)
# Out:
# /var/folders/76/z1mjvk1s7k36fwnyfkcvx1q40000gn/T/ipykernel_2016/403609910.py:22: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax3.legend()
# <BarContainer object of 2 artists>

# %%
titanic_gender
# Out:
# Sex
# male      29
# female    21
# Name: count, dtype: int64
